# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import datetime
import numpy as np
import seaborn as sns
import re
import json
import pandas as pd
import math
import ast
import os
from collections import defaultdict
import sys
sys.path.append('..')
from utilities import logger
from utilities import configuration
from utilities import health_data

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.preprocessing import StandardScaler

from sklearn.neural_network import MLPClassifier

from scipy import sparse

# %%
config = configuration.get_config()
for key in config:
    print(f'{key:40} (type: {type(config[key])})')


logging = logger.init_logger(config['system_log'])
logging.debug('Logger has started ont notebook 09 Random sample of instances.ipynb ...')
# Out:
# system_log                               (type: <class 'str'>)
# json_file                                (type: <class 'str'>)
# train_val_json                           (type: <class 'str'>)
# heldout_json                             (type: <class 'str'>)
# unused_after_heldout_json                (type: <class 'str'>)
# unified_merged_file_cz                   (type: <class 'str'>)
# unified_merged_file_noncz                (type: <class 'str'>)
# unified_merged_file                      (type: <class 'str'>)
# data_path                                (type: <class 'str'>)
# cz_files                                 (type: <class 'list'>)
# noncz_files                              (type: <class 'list'>)
# 2023-11-15 09:42:36,088 - root - DEBUG - Logger has started ont notebook 09 Random sample of instances.ipynb ...

# %%
f = open(config['train_val_json'])
train_val_data = json.load(f)

all_admissions = []
for ix in train_val_data:
    all_admissions.append(
        health_data.Admission.from_dict_data(admit_id=int(ix), admission=train_val_data[ix])
        )
len(all_admissions)

# Dictionary organizing data by patient
patient2admissions = defaultdict(list)
for admission in all_admissions:
    code = admission.code
    patient2admissions[code].append(admission)

# Ordering patient list by discharge date (from back )
for patient_code in patient2admissions:
    admissions_list = patient2admissions[patient_code]
    admissions_list = sorted(admissions_list, key=lambda admission: admission.discharge_date, reverse=False)
    assert all([admissions_list[i].discharge_date <= admissions_list[i+1].discharge_date for i in range(len(admissions_list)-1)])
    patient2admissions[patient_code] = admissions_list

patient_count=0
valid_readmission_count=0
for patient_code in patient2admissions:
    patient_admissions = patient2admissions[patient_code]
    ix = 0 
    while ix < len(patient_admissions):
        readmission_code = patient_admissions[ix].readmission_code
        if health_data.ReadmissionCode.is_readmit(readmission_code):
            # Either is not the first admission (ix>0) or 
            # we don't have the patient previous admition (readmission close to begining of dataset) (admit-(2015-01-01))<28 days
            # assert ix>0 or (patient_admissions[ix].admit_date - datetime.datetime.fromisoformat('2015-01-01')).days<365
            if ix>0 and  patient_admissions[ix-1].is_valid_readmission(patient_admissions[ix]):
                patient_admissions[ix-1].add_readmission(patient_admissions[ix])
                valid_readmission_count+=1
        ix+=1
    patient_count+=1


print(f'Size of train_val data:   {len(all_admissions):,}')
print(f"Begining heldout:         {min([admission.discharge_date for admission in all_admissions])}")
print(f"End heldout:              {max([admission.discharge_date for admission in all_admissions])}")
print(f'Number of instances with readmissions: {valid_readmission_count} ({valid_readmission_count/len(all_admissions):.2%})')
# Out:
# Size of train_val data:   524,986
# Begining heldout:         2015-01-01 00:00:00
# End heldout:              2021-10-01 00:00:00
# Number of instances with readmissions: 50533 (9.63%)

# %%
rng = np.random.default_rng(seed=5348363479653547918)

train_indexes = rng.choice(range(len(all_admissions)),size=int(0.8*len(all_admissions)), replace=False)

# Checking that every time I am getting the same training instances ( and validation instances)
assert all(train_indexes[:3] ==np.array([478898, 46409, 322969]))
assert all(train_indexes[-3:] ==np.array([415014, 330673, 338415]))
assert hash(tuple(train_indexes))==2028319680436964623

train_indexes = set(train_indexes)

train = [admission for ix, admission in enumerate(all_admissions) if ix in train_indexes ]
validation = [admission for ix, admission in enumerate(all_admissions) if not ix in train_indexes ]

print(f'Size of training (before filter)=     {len(train):,}')
print(f'Size of validation (before filter)=   {len(validation):,}')

# Filtering missing values
train = list(filter(lambda admission: not admission.has_missing, train))
validation = list(filter(lambda admission: not admission.has_missing, validation))


# Filtering STILL_BORNS admissions
train = list(filter(lambda admission: admission.admit_category!=health_data.AdmitCategory.STILLBORN, train))
validation = list(filter(lambda admission: admission.admit_category!=health_data.AdmitCategory.STILLBORN, validation))

# Filtering CADAVER admissions
train = list(filter(lambda admission: admission.admit_category!=health_data.AdmitCategory.CADAVER, train))
validation = list(filter(lambda admission: admission.admit_category!=health_data.AdmitCategory.CADAVER, validation))


print(f'Size of training (after filter)=      {len(train):,}')
print(f'Size of validation (after filter)=    {len(validation):,}')
# Out:
# Size of training (before filter)=     419,988
# Size of validation (before filter)=   104,998
# Size of training (after filter)=      419,345
# Size of validation (after filter)=    104,861

# %%
vocab_diag, diagnosis_matrix = health_data.Admission.create_codes_matrix(train)
vocab_inter, intervention_matrix = health_data.Admission.create_intervention_matrix(train)
continuos_matrix = sparse.csr_matrix((health_data.Admission.continuos_matrix(train)))
categorical_matrix = sparse.csr_matrix(health_data.Admission.categorical_matrix(train))

print(f'diagnosis:          {diagnosis_matrix.shape}')
print(f'intervention:       {intervention_matrix.shape}')
print(f'continuos_matrix:   {continuos_matrix.shape}')
print(f'categorical_matrix: {categorical_matrix.shape}')
# Out:
# diagnosis:          (419345, 9546)
# intervention:       (419345, 7519)
# continuos_matrix:   (419345, 5)
# categorical_matrix: (419345, 13)

# %%
scaler = StandardScaler()

vocab_diag, diagnosis_matrix = health_data.Admission.create_codes_matrix(train)
vocab_inter, intervention_matrix = health_data.Admission.create_intervention_matrix(train)
continuos_matrix = sparse.csr_matrix(scaler.fit_transform(health_data.Admission.continuos_matrix(train)))
categorical_matrix = sparse.csr_matrix(health_data.Admission.categorical_matrix(train))

X_train = sparse.hstack([continuos_matrix,
                         categorical_matrix,
                         diagnosis_matrix.toarray(),
                         intervention_matrix.toarray(),
                         ])
y_train = health_data.Admission.get_y(train)

_, diagnosis_matrix_val = health_data.Admission.create_codes_matrix(validation, vocabulary=vocab_diag)
_, intervention_matrix_val = health_data.Admission.create_intervention_matrix(validation, vocabulary=vocab_inter)
continuos_matrix_val = sparse.csr_matrix(scaler.fit_transform(health_data.Admission.continuos_matrix(validation)))
categorical_matrix_val = sparse.csr_matrix(health_data.Admission.categorical_matrix(validation))

X_val = sparse.hstack([continuos_matrix_val,
                         categorical_matrix_val,
                         diagnosis_matrix_val.toarray(),
                         intervention_matrix_val.toarray(),
                         ])
y_val = health_data.Admission.get_y(validation)



print(f'X_train.shape = {X_train.shape}')
print(f'y_train.shape = {y_train.shape}')
print()
print(f'X_val.shape = {X_val.shape}')
print(f'y_val.shape = {y_val.shape}')
# Out:
# X_train.shape = (419345, 17083)
# y_train.shape = (419345,)
#
# X_val.shape = (104861, 17083)
# y_val.shape = (104861,)

# %% [markdown]
# ### Undersampling

# %%
ratio = 4 
print(f'Positive instance for each {ratio} negative instances')

number_of_positives_in_training = np.sum(y_train)
print(f'Number of positive examples:                       {number_of_positives_in_training} '\
      f'({number_of_positives_in_training/len(y_train):.2%})')

positive_x = X_train.tocsr()[y_train==1,:]
negative_x = X_train.tocsr()[y_train==0,:]

print(f'Positive instances matrix shape =                  {positive_x.shape}')
print(f'Negative instances matrix shape =                  {negative_x.shape}')


under_sampling_ix = np.random.choice(range(negative_x.shape[0]), size=number_of_positives_in_training*ratio, replace=False)
under_sampled_negative_x = negative_x[under_sampling_ix,:]

print(f'Undersampled Negative instances matrix shape =     {under_sampled_negative_x.shape}')

undersampled_x = sparse.vstack([positive_x,under_sampled_negative_x])

print(f'Combined positives + undersampled neg, new shape = {undersampled_x.shape}')

assert undersampled_x.shape[0]==number_of_positives_in_training*(ratio+1) and under_sampled_negative_x.shape[1]==X_train.shape[1]

undersampled_y = np.array([1]*number_of_positives_in_training + [0]*number_of_positives_in_training*ratio)


print(f'Undersampled target shape =                        {undersampled_y.shape}')
# X_train_under_sampled = X_train[under_sampling_ix,:]
# X_train_under_sampled.shape
# Out:
# Positive instance for each 4 negative instances
# Number of positive examples:                       17412 (4.15%)
# Positive instances matrix shape =                  (17412, 17083)
# Negative instances matrix shape =                  (401933, 17083)
# Undersampled Negative instances matrix shape =     (69648, 17083)
# Combined positives + undersampled neg, new shape = (87060, 17083)
# Undersampled target shape =                        (87060,)

# %% [markdown]
# ### Logistic Regression (Balanced)

# %%
print(' ** ** Logistic Regression ** **')
clf = LogisticRegression(random_state=0, max_iter=1000,class_weight='balanced').fit(X_train, y_train,)
y_true = y_train
y_pred = clf.predict(X_train)
print('** Results on Training **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')
print()


y_true = y_val
y_pred = clf.predict(X_val)
print('** Results on Training **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')
# Out:
#  ** ** Logistic Regression ** **
# /Users/marianomaisonnave/Environments/alc/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ** Results on Training **
# Precision= 0.090
# Recall=    0.765
# F1-score=  0.162
#
# ** Results on Training **
# Precision= 0.077
# Recall=    0.627
# F1-score=  0.137

# %% [markdown]
# ### Undersampled NN

# %%
print(' ** **   MLP   ** **')
clf = MLPClassifier(random_state=0, 
                    # early_stopping=True, 
                    # n_iter_no_change=200,
                    # validation_fraction=0.2, 
                    max_iter=1000, 
                    hidden_layer_sizes=(100,),
                    verbose=True)
clf.fit(undersampled_x, undersampled_y,)
y_true = y_train
y_pred = clf.predict(X_train)
print('** Results on Training **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')
print()


y_true = y_val
y_pred = clf.predict(X_val)
print('** Results on Validation **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')


# RATIO = 1
# Iteration 241, loss = 0.06847385
# Iteration 242, loss = 0.06996890
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# ** Results on Training **
# Precision= 0.097
# Recall=    0.976
# F1-score=  0.176

# ** Results on Validation **
# Precision= 0.063
# Recall=    0.648
# F1-score=  0.115
# Out:
#  ** **   MLP   ** **
# Iteration 1, loss = 0.47744679
# Iteration 2, loss = 0.44525451
# Iteration 3, loss = 0.43259685
# Iteration 4, loss = 0.42014210
# Iteration 5, loss = 0.40697968
# Iteration 6, loss = 0.39202644
# Iteration 7, loss = 0.37610618
# Iteration 8, loss = 0.35897297
# Iteration 9, loss = 0.34160117
# Iteration 10, loss = 0.32423760
# Iteration 11, loss = 0.30850399
# Iteration 12, loss = 0.29369930
# Iteration 13, loss = 0.28001763
# Iteration 14, loss = 0.26699416
# Iteration 15, loss = 0.25534652
# Iteration 16, loss = 0.24543357
# Iteration 17, loss = 0.23443974
# Iteration 18, loss = 0.22518577
# Iteration 19, loss = 0.21678208
# Iteration 20, loss = 0.20912120
# Iteration 21, loss = 0.20209801
# Iteration 22, loss = 0.19625250
# Iteration 23, loss = 0.18890269
# Iteration 24, loss = 0.18293732
# Iteration 25, loss = 0.17846523
# Iteration 26, loss = 0.17266426
# Iteration 27, loss = 0.16756364
# Iteration 28, loss = 0.16343038
# Iteration 29, loss = 0.15979185
# Iteration 30, loss = 0.15522989
# Iteration 31, loss = 0.15170540
# Iteration 32, loss = 0.14847026
# Iteration 33, loss = 0.14549533
# Iteration 34, loss = 0.14271733
# Iteration 35, loss = 0.13901556
# Iteration 36, loss = 0.13672262
# Iteration 37, loss = 0.13379065
# Iteration 38, loss = 0.13166461
# Iteration 39, loss = 0.12919193
# Iteration 40, loss = 0.12749042
# Iteration 41, loss = 0.12555404
# Iteration 42, loss = 0.12320718
# Iteration 43, loss = 0.12164212
# Iteration 44, loss = 0.11906316
# Iteration 45, loss = 0.11747705
# Iteration 46, loss = 0.11600114
# Iteration 47, loss = 0.11443936
# Iteration 48, loss = 0.11289652
# Iteration 49, loss = 0.11205544
# Iteration 50, loss = 0.11014053
# Iteration 51, loss = 0.10891277
# Iteration 52, loss = 0.10748164
# Iteration 53, loss = 0.10664208
# Iteration 54, loss = 0.10498362
# Iteration 55, loss = 0.10433965
# Iteration 56, loss = 0.10289688
# Iteration 57, loss = 0.10232676
# Iteration 58, loss = 0.10132679
# Iteration 59, loss = 0.10024788
# Iteration 60, loss = 0.09925812
# Iteration 61, loss = 0.09878732
# Iteration 62, loss = 0.09782015
# Iteration 63, loss = 0.09658444
# Iteration 64, loss = 0.09561056
# Iteration 65, loss = 0.09635138
# Iteration 66, loss = 0.09479565
# Iteration 67, loss = 0.09365150
# Iteration 68, loss = 0.09290365
# Iteration 69, loss = 0.09215108
# Iteration 70, loss = 0.09326324
# Iteration 71, loss = 0.09125766
# Iteration 72, loss = 0.09078342
# Iteration 73, loss = 0.08973837
# Iteration 74, loss = 0.08941578
# Iteration 75, loss = 0.08877672
# Iteration 76, loss = 0.08811460
# Iteration 77, loss = 0.08774881
# Iteration 78, loss = 0.08854652
# Iteration 79, loss = 0.08690948
# Iteration 80, loss = 0.08587760
# Iteration 81, loss = 0.08580375
# Iteration 82, loss = 0.08595897
# Iteration 83, loss = 0.08482677
# Iteration 84, loss = 0.08466150
# Iteration 85, loss = 0.08389615
# Iteration 86, loss = 0.08322824
# Iteration 87, loss = 0.08340101
# Iteration 88, loss = 0.08303955
# Iteration 89, loss = 0.08249620
# Iteration 90, loss = 0.08280026
# Iteration 91, loss = 0.08131782
# Iteration 92, loss = 0.08166711
# Iteration 93, loss = 0.08103005
# Iteration 94, loss = 0.08078627
# Iteration 95, loss = 0.08049191
# Iteration 96, loss = 0.08025979
# Iteration 97, loss = 0.08115316
# Iteration 98, loss = 0.07971969
# Iteration 99, loss = 0.07883845
# Iteration 100, loss = 0.07879795
# Iteration 101, loss = 0.07834991
# Iteration 102, loss = 0.07791099
# Iteration 103, loss = 0.07787492
# Iteration 104, loss = 0.07791003
# Iteration 105, loss = 0.07764534
# Iteration 106, loss = 0.07764192
# Iteration 107, loss = 0.07854429
# Iteration 108, loss = 0.07709435
# Iteration 109, loss = 0.07614301
# Iteration 110, loss = 0.07583061
# Iteration 111, loss = 0.07646558
# Iteration 112, loss = 0.07572348
# Iteration 113, loss = 0.07602400
# Iteration 114, loss = 0.07523561
# Iteration 115, loss = 0.07501824
# Iteration 116, loss = 0.07495454
# Iteration 117, loss = 0.07496713
# Iteration 118, loss = 0.07421621
# Iteration 119, loss = 0.07392695
# Iteration 120, loss = 0.07401010
# Iteration 121, loss = 0.07360952
# Iteration 122, loss = 0.07291496
# Iteration 123, loss = 0.07337388
# Iteration 124, loss = 0.07308786
# Iteration 125, loss = 0.07349460
# Iteration 126, loss = 0.07506516
# Iteration 127, loss = 0.07248854
# Iteration 128, loss = 0.07215912
# Iteration 129, loss = 0.07261926
# Iteration 130, loss = 0.07233988
# Iteration 131, loss = 0.07213946
# Iteration 132, loss = 0.07220193
# Iteration 133, loss = 0.07155392
# Iteration 134, loss = 0.07172678
# Iteration 135, loss = 0.07186897
# Iteration 136, loss = 0.07121697
# Iteration 137, loss = 0.07134823
# Iteration 138, loss = 0.07064052
# Iteration 139, loss = 0.07087556
# Iteration 140, loss = 0.07086682
# Iteration 141, loss = 0.06997719
# Iteration 142, loss = 0.07064661
# Iteration 143, loss = 0.07007150
# Iteration 144, loss = 0.07031016
# Iteration 145, loss = 0.06997246
# Iteration 146, loss = 0.07004863
# Iteration 147, loss = 0.06986316
# Iteration 148, loss = 0.07097713
# Iteration 149, loss = 0.07007061
# Iteration 150, loss = 0.06931387
# Iteration 151, loss = 0.06935258
# Iteration 152, loss = 0.06950905
# Iteration 153, loss = 0.06870178
# Iteration 154, loss = 0.06851165
# Iteration 155, loss = 0.06863283
# Iteration 156, loss = 0.06873630
# Iteration 157, loss = 0.06916433
# Iteration 158, loss = 0.06828561
# Iteration 159, loss = 0.06837641
# Iteration 160, loss = 0.06834484
# Iteration 161, loss = 0.06816130
# Iteration 162, loss = 0.06865292
# Iteration 163, loss = 0.06769780
# Iteration 164, loss = 0.06780086
# Iteration 165, loss = 0.06810506
# Iteration 166, loss = 0.06762756
# Iteration 167, loss = 0.06715199
# Iteration 168, loss = 0.06715470
# Iteration 169, loss = 0.06726577
# Iteration 170, loss = 0.06710483
# Iteration 171, loss = 0.06726903
# Iteration 172, loss = 0.06820152
# Iteration 173, loss = 0.06825443
# Iteration 174, loss = 0.06678027
# Iteration 175, loss = 0.06677862
# Iteration 176, loss = 0.06712320
# Iteration 177, loss = 0.06673922
# Iteration 178, loss = 0.06628810
# Iteration 179, loss = 0.06640647
# Iteration 180, loss = 0.06603261
# Iteration 181, loss = 0.06642996
# Iteration 182, loss = 0.06695266
# Iteration 183, loss = 0.06591616
# Iteration 184, loss = 0.06593856
# Iteration 185, loss = 0.06602686
# Iteration 186, loss = 0.06540955
# Iteration 187, loss = 0.06579060
# Iteration 188, loss = 0.06569587
# Iteration 189, loss = 0.06580584
# Iteration 190, loss = 0.06545793
# Iteration 191, loss = 0.06537659
# Iteration 192, loss = 0.06537293
# Iteration 193, loss = 0.06527595
# Iteration 194, loss = 0.06510090
# Iteration 195, loss = 0.06551818
# Iteration 196, loss = 0.06503698
# Iteration 197, loss = 0.06483445
# Iteration 198, loss = 0.06578584
# Iteration 199, loss = 0.06445861
# Iteration 200, loss = 0.06511266
# Iteration 201, loss = 0.06619448
# Iteration 202, loss = 0.06566329
# Iteration 203, loss = 0.06443526
# Iteration 204, loss = 0.06453504
# Iteration 205, loss = 0.06484014
# Iteration 206, loss = 0.06401397
# Iteration 207, loss = 0.06481322
# Iteration 208, loss = 0.06404933
# Iteration 209, loss = 0.06436748
# Iteration 210, loss = 0.06366780
# Iteration 211, loss = 0.06407920
# Iteration 212, loss = 0.06410799
# Iteration 213, loss = 0.06441217
# Iteration 214, loss = 0.06438839
# Iteration 215, loss = 0.06394031
# Iteration 216, loss = 0.06405484
# Iteration 217, loss = 0.06387113
# Iteration 218, loss = 0.06377365
# Iteration 219, loss = 0.06343247
# Iteration 220, loss = 0.06355146
# Iteration 221, loss = 0.06370959
# Iteration 222, loss = 0.06314928
# Iteration 223, loss = 0.06351359
# Iteration 224, loss = 0.06439780
# Iteration 225, loss = 0.06379603
# Iteration 226, loss = 0.06367703
# Iteration 227, loss = 0.06431410
# Iteration 228, loss = 0.06271741
# Iteration 229, loss = 0.06323925
# Iteration 230, loss = 0.06263366
# Iteration 231, loss = 0.06278662
# Iteration 232, loss = 0.06312560
# Iteration 233, loss = 0.06240819
# Iteration 234, loss = 0.06274310
# Iteration 235, loss = 0.06266452
# Iteration 236, loss = 0.06278766
# Iteration 237, loss = 0.06287020
# Iteration 238, loss = 0.06192021
# Iteration 239, loss = 0.06261977
# Iteration 240, loss = 0.06304696
# Iteration 241, loss = 0.06311064
# Iteration 242, loss = 0.06240408
# Iteration 243, loss = 0.06261730
# Iteration 244, loss = 0.06223787
# Iteration 245, loss = 0.06195296
# Iteration 246, loss = 0.06223943
# Iteration 247, loss = 0.06254124
# Iteration 248, loss = 0.06236153
# Iteration 249, loss = 0.06186618
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# ** Results on Training **
# Precision= 0.233
# Recall=    0.937
# F1-score=  0.374
#
# ** Results on Validation **
# Precision= 0.078
# Recall=    0.296
# F1-score=  0.123

# %%
print(' ** **   SVM (RBF)   ** **')
clf = SVC(random_state=0, kernel='rbf', max_iter=10000,class_weight='balanced').fit(X_train, y_train.ravel(),)
y_true = y_train
y_pred = clf.predict(X_train)
print('** Results on Training **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')
print()


y_true = y_val
y_pred = clf.predict(X_val)
print('** Results on Training **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')
# Out:
#  ** **   SVM (RBF)   ** **
# /Users/marianomaisonnave/Environments/alc/lib/python3.9/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=10000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ** Results on Training **
# Precision= 0.042
# Recall=    0.990
# F1-score=  0.081
#
# ** Results on Training **
# Precision= 0.044
# Recall=    0.976
# F1-score=  0.084

# %%
y_va.shape
# Out:
# (419345, 17083)

# %%
print(' ** **   MLP   ** **')
clf = MLPClassifier(random_state=0, 
                    # early_stopping=True, 
                    # n_iter_no_change=200,
                    # validation_fraction=0.2, 
                    max_iter=1000, 
                    hidden_layer_sizes=(100,),
                    verbose=True)
clf.fit(X_train, y_train)
y_true = y_train
y_pred = clf.predict(X_train)
print('** Results on Training **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')
print()


y_true = y_val
y_pred = clf.predict(X_val)
print('** Results on Validation **')
print(f'Precision= {precision_score(y_true, y_pred,):4.3f}')
print(f'Recall=    {recall_score(y_true, y_pred,):4.3f}')
print(f'F1-score=  {f1_score(y_true, y_pred,):4.3f}')

# Iteration 192, loss = 0.05301263
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# ** Results on Training **
# Precision= 0.967
# Recall=    0.752
# F1-score=  0.846

# ** Results on Validation **
# Precision= 0.091
# Recall=    0.054
# F1-score=  0.068
# Out:
#  ** **   MLP   ** **
# Iteration 1, loss = 0.17170415
# Iteration 2, loss = 0.15946111
# Iteration 3, loss = 0.15785508
# Iteration 4, loss = 0.15661386
# Iteration 5, loss = 0.15512396
# Iteration 6, loss = 0.15331318
# Iteration 7, loss = 0.15141291
# Iteration 8, loss = 0.14938711
# Iteration 9, loss = 0.14733772
# Iteration 10, loss = 0.14531048
# Iteration 11, loss = 0.14331910
# Iteration 12, loss = 0.14131980
# Iteration 13, loss = 0.13926195
# Iteration 14, loss = 0.13696274
# Iteration 15, loss = 0.13462112
# Iteration 16, loss = 0.13207356
# Iteration 17, loss = 0.12930444
# Iteration 18, loss = 0.12655796
# Iteration 19, loss = 0.12379298
# Iteration 20, loss = 0.12108977
# Iteration 21, loss = 0.11863595
# Iteration 22, loss = 0.11600631
# Iteration 23, loss = 0.11351117
# Iteration 24, loss = 0.11114954
# Iteration 25, loss = 0.10870817
# Iteration 26, loss = 0.10658731
# Iteration 27, loss = 0.10429627
# Iteration 28, loss = 0.10270786
# Iteration 29, loss = 0.10085632
# Iteration 30, loss = 0.09902174
# Iteration 31, loss = 0.09726644
# Iteration 32, loss = 0.09543073
# Iteration 33, loss = 0.09386279
# Iteration 34, loss = 0.09222816
# Iteration 35, loss = 0.09066771
# Iteration 36, loss = 0.08940917
# Iteration 37, loss = 0.08790049
# Iteration 38, loss = 0.08661973
# Iteration 39, loss = 0.08546272
# Iteration 40, loss = 0.08411169
# Iteration 41, loss = 0.08303926
# Iteration 42, loss = 0.08201062
# Iteration 43, loss = 0.08095092
# Iteration 44, loss = 0.07994044
# Iteration 45, loss = 0.07902392
# Iteration 46, loss = 0.07810420
# Iteration 47, loss = 0.07728358
# Iteration 48, loss = 0.07630513
# Iteration 49, loss = 0.07570061
# Iteration 50, loss = 0.07464326
# Iteration 51, loss = 0.07411807
# Iteration 52, loss = 0.07344278
# Iteration 53, loss = 0.07272593
# Iteration 54, loss = 0.07195860
# Iteration 55, loss = 0.07144115
# Iteration 56, loss = 0.07080728
# Iteration 57, loss = 0.07034164
# Iteration 58, loss = 0.06970785
# Iteration 59, loss = 0.06938336
# Iteration 60, loss = 0.06862818
# Iteration 61, loss = 0.06842060
# Iteration 62, loss = 0.06769873
# Iteration 63, loss = 0.06717640
# Iteration 64, loss = 0.06678863
# Iteration 65, loss = 0.06652084
# Iteration 66, loss = 0.06609152
# Iteration 67, loss = 0.06555566
# Iteration 68, loss = 0.06551540
# Iteration 69, loss = 0.06509044
# Iteration 70, loss = 0.06472182
# Iteration 71, loss = 0.06429837
# Iteration 72, loss = 0.06400044
# Iteration 73, loss = 0.06366731
# Iteration 74, loss = 0.06345642
# Iteration 75, loss = 0.06311792
# Iteration 76, loss = 0.06271543
# Iteration 77, loss = 0.06240999
# Iteration 78, loss = 0.06210873
# Iteration 79, loss = 0.06203199
# Iteration 80, loss = 0.06178169
# Iteration 81, loss = 0.06147168
# Iteration 82, loss = 0.06139971
# Iteration 83, loss = 0.06096978
# Iteration 84, loss = 0.06098545
# Iteration 85, loss = 0.06062504
# Iteration 86, loss = 0.06015383
# Iteration 87, loss = 0.06036554
# Iteration 88, loss = 0.06020329
# Iteration 89, loss = 0.06000110
# Iteration 90, loss = 0.05968811
# Iteration 91, loss = 0.05945444
# Iteration 92, loss = 0.05947891
# Iteration 93, loss = 0.05910693
# Iteration 94, loss = 0.05920204
# Iteration 95, loss = 0.05879904
# Iteration 96, loss = 0.05880668
# Iteration 97, loss = 0.05859117
# Iteration 98, loss = 0.05855911
# Iteration 99, loss = 0.05837230
# Iteration 100, loss = 0.05809724
# Iteration 101, loss = 0.05804628
# Iteration 102, loss = 0.05799837
# Iteration 103, loss = 0.05774455
# Iteration 104, loss = 0.05763237
# Iteration 105, loss = 0.05752430
# Iteration 106, loss = 0.05729063
# Iteration 107, loss = 0.05738013
# Iteration 108, loss = 0.05726093
# Iteration 109, loss = 0.05698938
# Iteration 110, loss = 0.05694078
# Iteration 111, loss = 0.05694636
# Iteration 112, loss = 0.05686741
# Iteration 113, loss = 0.05682923
# Iteration 114, loss = 0.05676394
# Iteration 115, loss = 0.05646234
# Iteration 116, loss = 0.05645709
# Iteration 117, loss = 0.05621088
# Iteration 118, loss = 0.05625022
# Iteration 119, loss = 0.05649606
# Iteration 120, loss = 0.05608922
# Iteration 121, loss = 0.05603367
# Iteration 122, loss = 0.05597511
# Iteration 123, loss = 0.05583799
# Iteration 124, loss = 0.05585054
# Iteration 125, loss = 0.05594363
# Iteration 126, loss = 0.05567484
# Iteration 127, loss = 0.05548209
# Iteration 128, loss = 0.05542977
# Iteration 129, loss = 0.05551486
# Iteration 130, loss = 0.05555863
# Iteration 131, loss = 0.05530742
# Iteration 132, loss = 0.05516749
# Iteration 133, loss = 0.05533855
# Iteration 134, loss = 0.05508387
# Iteration 135, loss = 0.05502748
# Iteration 136, loss = 0.05495408
# Iteration 137, loss = 0.05490278
# Iteration 138, loss = 0.05482935
# Iteration 139, loss = 0.05465707
# Iteration 140, loss = 0.05468444
# Iteration 141, loss = 0.05457028
# Iteration 142, loss = 0.05488224
# Iteration 143, loss = 0.05553741
# Iteration 144, loss = 0.05487830
# Iteration 145, loss = 0.05444531
# Iteration 146, loss = 0.05431388
# Iteration 147, loss = 0.05450956
# Iteration 148, loss = 0.05427310
# Iteration 149, loss = 0.05419901
# Iteration 150, loss = 0.05434180
# Iteration 151, loss = 0.05404426
# Iteration 152, loss = 0.05413474
# Iteration 153, loss = 0.05421655
# Iteration 154, loss = 0.05385277
# Iteration 155, loss = 0.05405206
# Iteration 156, loss = 0.05386148
# Iteration 157, loss = 0.05435687
# Iteration 158, loss = 0.05448099
# Iteration 159, loss = 0.05389344
# Iteration 160, loss = 0.05363715
# Iteration 161, loss = 0.05369771
# Iteration 162, loss = 0.05377851
# Iteration 163, loss = 0.05366741
# Iteration 164, loss = 0.05352788
# Iteration 165, loss = 0.05373092
# Iteration 166, loss = 0.05362076
# Iteration 167, loss = 0.05347043
# Iteration 168, loss = 0.05373726
# Iteration 169, loss = 0.05349815
# Iteration 170, loss = 0.05339069
# Iteration 171, loss = 0.05334591
# Iteration 172, loss = 0.05353895
# Iteration 173, loss = 0.05316326
# Iteration 174, loss = 0.05328704
# Iteration 175, loss = 0.05346726
# Iteration 176, loss = 0.05309365
# Iteration 177, loss = 0.05331661
# Iteration 178, loss = 0.05319509
# Iteration 179, loss = 0.05312586
# Iteration 180, loss = 0.05318168
# Iteration 181, loss = 0.05290290
# Iteration 182, loss = 0.05304224
# Iteration 183, loss = 0.05295894
# Iteration 184, loss = 0.05289038
# Iteration 185, loss = 0.05301799
# Iteration 186, loss = 0.05319552
# Iteration 187, loss = 0.05287537
# Iteration 188, loss = 0.05291599
# Iteration 189, loss = 0.05283883
# Iteration 190, loss = 0.05292720
# Iteration 191, loss = 0.05285559
# Iteration 192, loss = 0.05301263
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# ** Results on Training **
# Precision= 0.967
# Recall=    0.752
# F1-score=  0.846
#
# ** Results on Validation **
# Precision= 0.091
# Recall=    0.054
# F1-score=  0.068
